# %% [markdown]
# <a href="https://colab.research.google.com/github/kakdevedant2018/PML/blob/main/DGA_detection_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (8.1.3)

# %%
df = pd.read_csv("/content/drive/MyDrive/DGA_data/dga_data.csv")

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df
# Out:
#         isDGA                      domain                            host  \
# 0         dga  6xzxsw3sokvg1tc752y1a6p0af  6xzxsw3sokvg1tc752y1a6p0af.com
# 1         dga              glbtlxwwhbnpxs               glbtlxwwhbnpxs.ru
# 2         dga              xxmamopyipbfpk               xxmamopyipbfpk.ru
# 3         dga   zfd5szpi18i85wj9uy13l69rg   zfd5szpi18i85wj9uy13l69rg.net
# 4         dga                jpqftymiuver                 jpqftymiuver.ru
# ...       ...                         ...                             ...
# 159995  legit                     manhunt                     manhunt.net
# 159996  legit                      yupptv                      yupptv.com
# 159997  legit                    bbcmundo                    bbcmundo.com
# 159998  legit                   kanogames                   kanogames.com
# 159999  legit                   roadrover                    roadrover.cn
#
#             subclass
# 0        gameoverdga
# 1       cryptolocker
# 2       cryptolocker
# 3             newgoz
# 4       cryptolocker
# ...              ...
# 159995         alexa
# 159996         alexa
# 159997         legit
# 159998         legit
# 159999         alexa
#
# [160000 rows x 4 columns]

# %%
df= df.drop(["domain"],axis=1)

# %%
df=df.drop(["subclass"],axis=1)

# %%
df
# Out:
#         isDGA                            host
# 0         dga  6xzxsw3sokvg1tc752y1a6p0af.com
# 1         dga               glbtlxwwhbnpxs.ru
# 2         dga               xxmamopyipbfpk.ru
# 3         dga   zfd5szpi18i85wj9uy13l69rg.net
# 4         dga                 jpqftymiuver.ru
# ...       ...                             ...
# 159995  legit                     manhunt.net
# 159996  legit                      yupptv.com
# 159997  legit                    bbcmundo.com
# 159998  legit                   kanogames.com
# 159999  legit                    roadrover.cn
#
# [160000 rows x 2 columns]

# %%
df["num_characters"]=df["host"].apply(len)

# %% [markdown]
# # Vowel count

# %%
df['Vowels'] = df.host.str.lower().str.count(r'[aeiou]')

# %% [markdown]
# # consonant

# %%
df['Consonant'] = df.host.str.lower().str.count(r'[a-z]') - df['Vowels']

# %%
df
# Out:
#         isDGA                            host  num_characters  Vowels  \
# 0         dga  6xzxsw3sokvg1tc752y1a6p0af.com              30       4
# 1         dga               glbtlxwwhbnpxs.ru              17       1
# 2         dga               xxmamopyipbfpk.ru              17       4
# 3         dga   zfd5szpi18i85wj9uy13l69rg.net              29       4
# 4         dga                 jpqftymiuver.ru              15       4
# ...       ...                             ...             ...     ...
# 159995  legit                     manhunt.net              11       3
# 159996  legit                      yupptv.com              10       2
# 159997  legit                    bbcmundo.com              12       3
# 159998  legit                   kanogames.com              13       5
# 159999  legit                    roadrover.cn              12       4
#
#         Consonant
# 0              16
# 1              15
# 2              12
# 3              14
# 4              10
# ...           ...
# 159995          7
# 159996          7
# 159997          8
# 159998          7
# 159999          7
#
# [160000 rows x 5 columns]

# %% [markdown]
# # Feature Generation
# used to extract the features.
#
# The linguistic features are
# 1. length
# 2. Meaningful word Ratio
# 3. Percentage of Numerical character
# 4. Pronounceability score
# 5. Percentage of length of the largest meaningful Sring
# 6. Levenshtein edit distance
# 7. Unique Character rate
# 8. vowel count
# 9. entropy

# %% [markdown]
# # Length
# The length of the domain name |d| is an important feature.The most DGA domain have greateer length thatn normal domain thus it introduced as a feature.
# As the length increases probability of being DGA domain are also increase.

# %% [markdown]
# # Meaningful word ratio:
# It is the ratio of number of meaningful words in a domain name to the total length of the domain name.
# The words in the domain name are compared to the standard meaningful word list and ratio is calculated.
# DGA domain have less meaningful words than legitimate domain names.

# %% [markdown]
# #  Unique character rate.
# It is the measure of unique characters and if lower unique character rate implies a DGA domain.

# %%
# df["Unique Character rate"] = len(set(df["host"]))/df["host"].str.len()

# %%
s = "shriya"
print(len(set(s))/len(s))
# Out:
# 1.0

# %%
len(set(df["host"]))
# Out:
# 159235

# %%
l=[]

# %%
for i in df["host"]:
  l.append(len(set(i)))

# %%
l[0]
# Out:
# 23

# %%
l1=[]

# %%
for i in df["host"]:
  l1.append(len(i))

# %%
k=[]
for i in range(160000 ):
  j=l[i]/l1[i]
  k.append(j)
df["Unique characters ratio"]=k

# %%
l1[1]
# Out:
# 17

# %%
l[1]
# Out:
# 13

# %%
l1[0]
# Out:
# 30

# %%
df
# Out:
#         isDGA                            host  num_characters  Vowels  \
# 0         dga  6xzxsw3sokvg1tc752y1a6p0af.com              30       4
# 1         dga               glbtlxwwhbnpxs.ru              17       1
# 2         dga               xxmamopyipbfpk.ru              17       4
# 3         dga   zfd5szpi18i85wj9uy13l69rg.net              29       4
# 4         dga                 jpqftymiuver.ru              15       4
# ...       ...                             ...             ...     ...
# 159995  legit                     manhunt.net              11       3
# 159996  legit                      yupptv.com              10       2
# 159997  legit                    bbcmundo.com              12       3
# 159998  legit                   kanogames.com              13       5
# 159999  legit                    roadrover.cn              12       4
#
#         Consonant  Unique characters ratio
# 0              16                 0.766667
# 1              15                 0.764706
# 2              12                 0.764706
# 3              14                 0.793103
# 4              10                 0.866667
# ...           ...                      ...
# 159995          7                 0.727273
# 159996          7                 0.900000
# 159997          8                 0.666667
# 159998          7                 0.769231
# 159999          7                 0.750000
#
# [160000 rows x 6 columns]

# %% [markdown]
# # Percentage of numerical characters:

# %%
host =[]

# %%
for i in df["host"]:
  host.append(i)

# %%
host
# Out:
# ['6xzxsw3sokvg1tc752y1a6p0af.com',
#  'glbtlxwwhbnpxs.ru',
#  'xxmamopyipbfpk.ru',
#  'zfd5szpi18i85wj9uy13l69rg.net',
#  'jpqftymiuver.ru',
#  'takenroll.net',
#  'vrrtneoswsds.ru',
#  'mzapiwbcsbqiyxnlxa1hprx8n.com',
#  'xkoihiygtanuio.ru',
#  'dreamdont.net',
#  'visitshot.net',
#  'lpeespobepdxy.ru',
#  'wcsdwvdbpimqg.ru',
#  'rcdqeqmpxgdiuqombhuwcfu.ru',
#  'cmkrdurmtrhjylp.ru',
#  'plsibgabyyjbjc.ru',
#  'qrnafqrigldcjaa.ru',
#  'n3m4txqpb6a415iwzkrmdzgk6.com',
#  '1rw1pc44mkxp4qjx18qua26.net',
#  'itpkkibmmxao.ru',
#  'putisrswuvpk.ru',
#  '1x75xo41t4fno51wc86e1y4s13d.net',
#  'mostjune.net',
#  '1y6oppp7k3pwfpo2sfmkloyxa.biz',
#  'kctkokkiiavumpq.ru',
#  'dtfbtfrobxlle.ru',
#  'fairslow.net',
#  'sfmbdpnijlarq.cc',
#  'vdqqfdcax.im',
#  'svwivgcgkbgt.ru',
#  '1t5fkef5u26di8wtme9ezjamn.com',
#  'bfxfbdutaessry.ru',
#  'aedwiugahlyv.ru',
#  'njtvrfhfaklho.sc',
#  'qulohywkisgu.org',
#  '14ua4ir7rwqzv15mes59zpel1a.net',
#  '130qnn0srp6su1bosz2z19gx1a7.net',
#  'wawft814u5se21tmptb51yy47q2.org',
#  'by86yc1p7f81d1tb5g7h1el8t9k.org',
#  'jxnpnxdgmunsxah.ru',
#  'triedlady.net',
#  'hrbikrmyoxueqd.ru',
#  'jlkoy1mddlu81htl8cu13phhqf.org',
#  'xgcfrfatrutueho.co.uk',
#  'fnbxw68p8e2l9qeq531wp37f2.com',
#  'movemarch.net',
#  '1y363y8izjhuol3ym91wdpdqr.biz',
#  'dejectaxtsumvws.ru',
#  'x3rv4x124bm7s1ik7tqi1tiwojo.biz',
#  '10z55t9lizwjo1ymilos13w3q69.com',
#  'drinkusual.net',
#  'emdwdmjkrnflp.ru',
#  'jrxrovxkbemgqutopblbbfe.ru',
#  'hsmcnwof.mx',
#  '1qkqxw21tgtfmw1bib3b9ccgacn.org',
#  'dixnzhelzukwsojfxuivlamadu.ru',
#  'adtimdfqeitl.info',
#  'mcedlrfqaqjcypqwhmio.de',
#  'vjidtkoywixjlb.ru',
#  'dlnvsflboujy.ru',
#  '1h0lw6219iy6moq1sc6lt5lpwg.net',
#  '1b798o1tq8fpp1kegata1djbflv.com',
#  'wpplovoekprxh.ru',
#  'xmkrdivvpvtektxuvy.xxx',
#  '1asn83b1bxcccz1emrj1mjxrrip.org',
#  '1m6kynyott35x196hh0av9i9wp.com',
#  'pueak3118xdgo1wlhwgkyd9isl.com',
#  'vmkeexjfralx.ru',
#  'xjjbxjdgkfnkd.ru',
#  'kxajlryrvkrlye.ru',
#  '1i6b4hpzzeklu1pzbwwnit1f6u.com',
#  'nyvccjxpemjku.ru',
#  'jhetmkyytswih.ru',
#  'oudaunswdtmys.ru',
#  '1y2v376b2osnc1h8g0dslymlk4.biz',
#  'intjkdhpisjj.ru',
#  'doturvftbvaup.co.uk',
#  '1h6c78615v2p7011v5exrvg0xow.org',
#  'iz2gkk1tgvjkw1tg5ndslxhk9.biz',
#  'dnulqjbjbqmc.ru',
#  '1a3xhheejnlur1cvdab0o4cpmv.org',
#  'audgrtrcdysyu.ru',
#  'lmwaodqeyximw.ru',
#  'caseought.net',
#  'ydhmbyhgypnkdpzcymnnjxcalfm.ru',
#  'enjsbygdpjrj.co.uk',
#  'takenshoe.net',
#  '17257kh12e03dd1h9icgx1nhwnhk.biz',
#  'mjkgbcajyq.com',
#  'f0gqslflbdmv17d3s771kek004.org',
#  'xgvfdxjlqc.ru',
#  '1a2wym5vfcyip1he4icp1dl0w69.com',
#  'umficyzdvcdpzbalvdmkjjvcm.ru',
#  'nvueycjulvsxvld.ru',
#  '1ylnnx51mig0lh1krkxjwrzq7fc.net',
#  'ztscylhitkplaemfiuxcubozmr.ru',
#  'mryumfsrfabwje.ru',
#  'gjjnhpllbgns.ru',
#  '1pn01qj5mlzog1o4r0su16b3rkw.com',
#  '38cs2p1wl54jbqxoafp1x5ahoq.net',
#  'dreamfind.net',
#  'xbgtjxurjvrk.biz',
#  'yhqwcsrfcthq.ru',
#  '8k6oo37xwwpwyp7iovdduz2b.com',
#  'gcshsqxovcma.ru',
#  'gftetponlgocityfeps.de',
#  'lpgtkmwtdvstyow.ru',
#  'vdgslndsowqag.ru',
#  'hmhmqmlwuuikqp.ru',
#  'uhjruympodvhxpc.ru',
#  'udwxobiyuvpg.ru',
#  'levfpxseobomr.ru',
#  'o23f0k1laqo8mnuev51iptq5u.com',
#  '1vkzpiccr9xcu1w5y852uqk5jy.biz',
#  'lolrdlackhskb.ru',
#  'popmewjorcnkjci.ru',
#  'imxdwdscghyqtik.ru',
#  'nmtixemfvcqg.ru',
#  '1002ra86698fjpgqke1cdvbk5.org',
#  'madpxhvetwmds.ru',
#  '1e5qax488e163secwpo1d8tqhr.com',
#  'zrwqtha1cc5r1y95tzz10jm134.org',
#  'hmlzvbopfkrgaztrsdexgjbgageon.ru',
#  'r0w7il7kzxyst08flb8ajv4c.net',
#  'nhtcrhnvtrhkat.ru',
#  '1vbfpcp1w1famctytruk1ff9hqp.biz',
#  'pfvttkzllvxnvgiobbejbayuolj.ru',
#  'stlmxiety29s1ncspk91tr2n7s.org',
#  'npvleeqrxjbyhrstdk.net',
#  'atbayewmbguhetk.net',
#  'xgbmgvfkwdutt.ru',
#  '1i84mkadxg1xtu2e5h1av2jf2.org',
#  'lbsqwvbolhlrw.ru',
#  'ofurndllkdvj.ru',
#  'lrnbqspjuuchnflvovrtolvpvy.ru',
#  'pqugaygdoiytswr.ru',
#  'wifelate.net',
#  'ileeiaexahaawgxfpenxj.org',
#  'ckwjfwcrumipo.ru',
#  '1yetgvhw117f914sqwe7qosku.net',
#  'bv16rv1wwtnif1fhiix21t305ur.net',
#  'qcrcnzfmxcaqtfyjzcypscdxtts.ru',
#  'sxcvfqgfynmcvd.net',
#  'lrhtgsjhcolbgpo.ru',
#  'v4ycl0ulckr81t2s8yo1i98bbu.biz',
#  'ntpibablqrfox.ru',
#  'nuhldialngeyt.net',
#  'yaeiovmkmssxyim.ru',
#  'drbtqmwcopxl.ru',
#  'svkufcsnqfup.ru',
#  'k1gr1s1z034in17mijfg1rbc8q.net',
#  'lzkrkvhehiskobwgwovoydmug.ru',
#  'buhgahqnrivvsormvaikrgpkjlu.ru',
#  'tlst1xe6b3kp3apbm81l9p28y.biz',
#  'nkfcqpaamfidyk.ru',
#  'yfcjwloujkcmil.biz',
#  'wlunqsqoyoiuih.ru',
#  '1polo0zbtpeiiochrv61t6h5bn.com',
#  '1czvanpcohoma19lek4d1m064cw.org',
#  'ukvgnhakeyuon.ru',
#  'hlsgafabsduw.ru',
#  'ogytnflfhbkltvj.ru',
#  'iymrowiyejbqwjurvvqvi.to',
#  'gladtell.net',
#  'scavsnd.com',
#  '1o7g1g41d3dixkld85ej79ttj.org',
#  'thesethan.net',
#  'pydhmbmieeetpg.la',
#  'geprgfbkmsofoe.ru',
#  'wqiawmmxbwxlpue.ru',
#  'qjjqw7b9nfhkip0a9j1doyxup.com',
#  '1ut6f5pidlaafo7lfh4zxxr6a.net',
#  'nvthheizkzxfirtekjhucmrh.ru',
#  'swxaqfrhejkw.ru',
#  'scozusrtuohqgeuweynkniztt.ru',
#  '1ref2oscjiuqp1beedz31802b7a.com',
#  'skmrpgieytlfdguwsqkpusdqwkws.ru',
#  'tigawxghjbrlibk.ru',
#  'dxsmlaoalpei.ru',
#  'q7lse62nmqqx1hzjrnu1526vjs.com',
#  'nprkdpkaicucapx.ru',
#  'l5pcoi1o59oxurc3ctq7dwwvc.com',
#  'uqkgagrucjlbwgt.pw',
#  '293yn2rk3kqove8ogz10ncwe6.com',
#  'fyuffmdtcjyk.ru',
#  'pzyprkzamojkojwswkpvqkxfyjz.ru',
#  '15f8ks31711xut1nsvjht1t4g6aw.net',
#  'n46qwv195nsh8fesdpe16598m.org',
#  '1kousuv15guyhwgqcfkrntngny.biz',
#  'whjhuclnbdbveum.ru',
#  'dykh9tqq7d1224tjf9s3h5ox.org',
#  'ubtvpyrqqfpu.ru',
#  '6jymq1lsqupn7x30sump2foi.org',
#  'wzfjlmu2284bd8m3ac1tcjir3.com',
#  'rsevnuwebnewj.ru',
#  'nbqypaecbhmofff.ru',
#  'bvctaltusycxp.ru',
#  'kmvnyejmivkyr.ru',
#  'fsfhimbhaisfwg.ru',
#  'qlftfivcmjfjih.ru',
#  'dreamfine.net',
#  'vocmfurghpjzddizhztukeqxsizyp.ru',
#  'cfqhblay.in',
#  'shxbrphjfejhoie.ru',
#  'ktyrlcmniddb.org',
#  'madehear.net',
#  'dcdihoper.mu',
#  'nkrgltscydgpno.ru',
#  'ylostbljgeeg.sh',
#  'kcbs1z153smqwj3yj5l1n5901o.net',
#  '70ksmf1luxj9k1hj6ohswk8ur3.org',
#  'cbl4k0ooxomhf5mpqtzrup67.net',
#  '9l69mqihjk234attxu1y6guqb.net',
#  'oaivvoatyhsmk.ru',
#  '1xhtubm1ugkena13e3ffu1ygehhh.net',
#  '18xx2is10myj2m1xedh06o5qa00.com',
#  'iifhbvbogsqos.ru',
#  '1vedw84g82him147cu5lt3zdbe.net',
#  'iiihatygnoylqgstgow.net',
#  '18ejj7b18dc4fj14asq1hz9ntfb.org',
#  'kyjoakbrggph.ru',
#  'ovctkhboceltvp.ru',
#  'q9kkg61bafxopsv6s651od4xyz.net',
#  'yhupvlaojsawwn.ru',
#  '16tomlv1hxty88c649w119vjvi.org',
#  'tgpysmjrnastxy.ru',
#  'oituqatsiabc.ru',
#  'v1p803mrq9npe5aiy1xn6jst.net',
#  'emaqdkcuhmtdr.ru',
#  'fwtsoffnakjwhrif1v5gbj9r.net',
#  'ondebufehtqyemreqkpayd.ru',
#  'wronghurry.net',
#  'iyowdlsaytlbw.eu',
#  '13ysg27xy7g8bb0xejd4vv7dy.com',
#  'spplmbvurfmdec.biz',
#  'knowpeace.net',
#  'tipafafrje.nf',
#  '147fdv6mb9udy1c1w7ui1dlku41.com',
#  'casegreen.net',
#  'kjwbtmimkavxqlj.ru',
#  'hwdrilqsoyyc.ru',
#  'hfxhlufdummiii.ru',
#  '1ugdqjq1004a7u1dqa14q1cq5o0o.com',
#  'satvncibnp.tw',
#  'qmplxqdpuvdsy.ru',
#  'sqdqkffhovxp.ru',
#  '14lm8zdpwxoeudeki7v1cgycoc.biz',
#  'cenwdjhwvyvos.com',
#  'mhmcbwoowlwm.ru',
#  'ksxfqhqfuecimos.ru',
#  '1ljqsc1zzzve2187de2g1t4a5w1.biz',
#  'dabxgqvpkwfakt.ru',
#  '1683k0qn0d6m4j9xyruqbyrb0.net',
#  '1outjf911ov3by196mamuqxxlu7.org',
#  'ifxytvsbekzcesoduzhddylrwx.ru',
#  'yz8rni1lf9kukliodtuwu7a0i.net',
#  'cvgnrbiohoeoiep.ru',
#  'ocx5nwx51zksm4393318s5xzs.com',
#  'lvsjmalnoqkqpxg.co.uk',
#  '5df9d44072820ad6eaac91669f357fea.org',
#  'hfnribqgwomhvydfljhx.ru',
#  'ceqgxlcukdvld.ru',
#  'qyaayesxwqtss.ru',
#  'threethrow.net',
#  'tvepkbniytsskxw.ru',
#  'gjeovxbydjvxd.ru',
#  'hebmcaswqkvfmydwcnjozxgdqr.ru',
#  '14vx4fhgblgex1i29j7y1po9tj5.biz',
#  'zz11dcd347ja1sb0w9xkjo9kv.net',
#  '1na23r9xnoamwem5tq21somyyb.org',
#  'tcijxyldyhtkpjsglfxcuhitca.ru',
#  'ks3gaw180t062iv6sys1yochyz.com',
#  'moq25dcjl51e1trnhc71b00uw8.org',
#  'gerwhdfufafmcibgqswvgkzjbtcv.ru',
#  '1926pt174ph361rhuqstp97667.net',
#  '1a80hhm7verus1f1bq79n0069a.com',
#  'iaxvtbvmfqhhlh.ru',
#  'hillgold.net',
#  'dtuklqmmsuujgx.ru',
#  '1bay72x15ymods1hnc2w31q49tbs.com',
#  'ttmdnvvaytdrm.co.uk',
#  'xxxgoqtqbphyw.bz',
#  'whichback.net',
#  '1dw1bar1a42dlt1vspn1p1mfcgfi.org',
#  'mjlrlyyqyvpnsh.ru',
#  'aajscswijgwdqc.ru',
#  'bsqtseqxjsiqtpu.ru',
#  'pmnxdhmlamycmwn.ru',
#  'kvxhupvzpgmkrhrslcuvswbilj.ru',
#  'tblnfxxjibsfj.ru',
#  'milkjune.net',
#  'ya63ux1xwmgl5hrua2e11bzi9b.com',
#  'widlnjwxpceyie.ru',
#  'quickcloth.net',
#  '1nookqv15m95wmcvo5g7ext7xc.biz',
#  'gxpqgsovvjsj.biz',
#  'xtjuuspnvxrmls.ru',
#  'zbilldihijbmbdskhxkxsosij.ru',
#  'wwencfvdyiroyh.ru',
#  'srgr2qb7z63915pjsshnnolz1.com',
#  'hcrfeuindfgbwsh.ru',
#  'wtfuobvdpelksa.ru',
#  '167o12epfm06n1nyuhvp726apk.net',
#  'jivwtbjvsgepiuu.ru',
#  'mbcvowtsknukpzpxkaqbutqwtt.ru',
#  'cebvaonpwvfge.ru',
#  'nqfmpogprkrin.ru',
#  'gkrgjaesccydpob.ru',
#  'cuxuntrmtsacei.ru',
#  'hoxaqufwcxto.ru',
#  'lyrejwobosrjrkm.ru',
#  'jmqdmqiowkxymu.ru',
#  'hyutmkklpccj.ru',
#  'chhsmbbwdjkpsd.ru',
#  'vrolmiiiahuhs.biz',
#  'huavztzpqwcidswouwzxlwsrgnv.ru',
#  'glcruvpbykxacde.ru',
#  'txxpvonmeakwfp.ru',
#  'fj60m519ah7lt19pt6ry1t0yfeg.biz',
#  'monkufxasvjr.org',
#  'pal5kr1hhopfe4kesu14036d6.com',
#  'npmjqgwjcywf.ru',
#  'a7fd378e8e64200f13421e6135a06dce.org',
#  'aglpebmfkrfx.biz',
#  'tjcplcccmttep.biz',
#  'tbeeervgbjmfk.ru',
#  'sorgydheqsgulpkrxovgbaqauin.ru',
#  'mpy1hvrpmg5q1h5gzyg1hugdm7.com',
#  'wrongtear.net',
#  'iy4tv714p3su9qbr8tb1ui8xu3.org',
#  'fzhkbykonamlzdvwtgxobqkj.ru',
#  'darkthan.net',
#  'jiwnqrvbvdxlkrn.ru',
#  '123xqnm115jy1d15qaki1wv0c45.com',
#  '13v5dvyy0w2jv1klh5f44uyg5a.biz',
#  'itvgggscpheag.ru',
#  'ncrnms1aiaen9bbtf8m17qvj1y.org',
#  'hmyxzhnfhvwwsfaovdgmldef.ru',
#  'ldlpkpbdjelp.net',
#  'j967zk1wd2t011lbzaqo1rr6sqq.org',
#  'lvmrprvyjfsnp.ru',
#  'yconxhvhehnjhv.ru',
#  'diya65fzfiv43x8ks5190wyw1.org',
#  'equalaugust.net',
#  '5ex9a814fm2jwyg8mxgpenwvh.biz',
#  'whichcompe.net',
#  'yepwhhkwqnxl.ru',
#  'wrongoctober.net',
#  'byxtbdnakvhghf.ru',
#  'hntfarwlevtcxm.ru',
#  'cmjctlbohgbb.ru',
#  'udncwcsbwcwi.ru',
#  'af6gpn14wma2219zj3c21l95tdp.biz',
#  'r6btuj1czimfxxo48ox1d05nuv.net',
#  'jljwkfhwbbbi.ru',
#  'iwxyfwrbnxob.biz',
#  'vcxngxswwijuig.org',
#  'wqwpnnfnvjvykhv.ru',
#  'dd82f8a0b2b6520e2706f704ba2a289a.org',
#  'songfloor.net',
#  'escuklcnxdflryv.ru',
#  'smjdbxncmispja.com',
#  'inlkfnwybslqndyilrehj.cm',
#  'rggooenfnealp.org',
#  'vqbmoxbsfgmu.net',
#  'eroqrmgifxqcv.ru',
#  'xalgjkctfswa.ru',
#  '555fzex4z05zb0ssw9962107.net',
#  'qukgmyukicmd.ru',
#  'adwditxbmcbmup.ru',
#  'gpqhogwqutker.ru',
#  'spendwhere.net',
#  'cf9sn110vldk11m87gxdtf36am.net',
#  'exonxoxplofb.ru',
#  'hangseven.net',
#  'wwzcdg1txqmucsf7liuj1lntg.net',
#  'btbvwtbhryyco.ru',
#  'xepriibvuahxcgrhud.bit',
#  'fwmxcdinvoutpn.org',
#  'drinkgrow.net',
#  'whichsuch.net',
#  'thenought.net',
#  '1ey4kgwfgbjyi1s0vtzo1n8u303.org',
#  'aagmku11m57sd137aczv1s0onrg.com',
#  '13zg9oi1l6l54a180n8zb1k09c5c.org',
#  'djqdwchhuxewpmy.ru',
#  'lpukkpsyacfcc.ru',
#  'b7do2auz9tgcsk1gfk9clpl9.org',
#  'wishmarry.net',
#  'tnfuteuuoskkrbyrkbezyhvkiv.ru',
#  '1rat3ent82pom6rysqd9929mw.org',
#  'u4roynrf6wow1otresxxnf94c.com',
#  'nohthuqmkkpwyy.ru',
#  'fvfacvrndmnspxa.ru',
#  'biudxepfkbtgfc.ru',
#  'dglimiuufsgpp.sx',
#  '1a1uy4f1fyml5uvj0yn10mpfy0.net',
#  '1huxngv1m5phm0ue7erfeu2syq.net',
#  'luhtixxgggquvwq.ru',
#  'wletqmsquxfbqm.co.uk',
#  'qhc3bsruqef3kvny5a15228ri.com',
#  'tchtxrmbaiyshu.ru',
#  'dgaqqdlegots.info',
#  '1618ms4hqjjppyfk5he1y4tsoo.com',
#  '6rv0nd1o3r4p05upe4rp9ayj5.com',
#  'oigrlpyqinppq.ru',
#  'dqugeycrtqfvab.net',
#  'hvumsuamsghsl.ru',
#  'sbjlmwwpkihev.ru',
#  'groupback.net',
#  'mmsxnpjeqxykh.ru',
#  'yardgift.net',
#  'emytboyacuairfc.com',
#  'kbtkcyeolxanaww.ru',
#  '08c9bb43ca6555de477ec262b078cb91.org',
#  'opnlyvikwugax.biz',
#  'tdmddipopqn.co',
#  'yaallipovalmv.ru',
#  '1hlyrz7m37wjh35dwko54f8ml.net',
#  '1ee0vyg1oazw8gwal7cmbyh23w.com',
#  'leabbehheihnage.ru',
#  'tomtiaohgjxqoa.info',
#  'tavtcctn.bit',
#  'lggnrskpvrtwa.ru',
#  'lbcdrnjjroebd.eu',
#  'ymjvgtguaqbf.biz',
#  '83da9e9c4491ea09a9b179199b31258f.org',
#  'xdrulrwtgqpkuob.ru',
#  'dyecvqysuuoi.info',
#  'wkxkhlnuinykm.ru',
#  'dutywrote.net',
#  'jawcitakmcwq.ru',
#  'qdipvltnapvvohw.ac',
#  'gmnmvibnbpfagm.ru',
#  'ek4mjf1wuwgei5zmf2cqb7rd6.net',
#  'mcaorfjfmpeasi.ru',
#  '16zoupsd1r6fm15o0v2c1hym15s.com',
#  'psrejdklojmhiyf.org',
#  'iuhruawspayf.ru',
#  'kemrojrcnxyvbpiienadv.ir',
#  'joinaunt.net',
#  'oluujqtebfbmx.ru',
#  'wuharipkgqkso.ru',
#  'qubwrhp.ga',
#  '1rg8i37ckbajw3b3qpm1qccp0e.com',
#  'pfofjfpccrfd.ru',
#  '1y9r53a1dtr0bznol6if3det6n.net',
#  'joinrest.net',
#  'takenlift.net',
#  '2fbzns1bo41wl1gknwn18v5hmg.org',
#  'audyg617pq9x41rdb0gh1ftr8e7.net',
#  'ohsvdaayvomp.info',
#  'kbcejbpbduxyxrcqzxlxwdwclrqk.ru',
#  'bgcyukdkspsf.ru',
#  'dbmmsjlggdrwxhu.ru',
#  'tucpixwfxyudn.info',
#  'caseborn.net',
#  '1xdaf417arul6qmyimcn2qoki.com',
#  'rg9kgq8yg5e51hddrnbh2hrkd.com',
#  'qfxvynmchquooh.org',
#  'yqfe9t8dd4991dd8cn71pglyq5.biz',
#  'aiwrsrwfxinns.co.uk',
#  'xwlfjhbuvdqsjo.com',
#  'vdntfvyiveke.ru',
#  'inpjxuaicklmpu.ru',
#  'v5zwkw1vlncjt11upaqi9h1bpg.org',
#  'k0h2lq17wilhsb1brmu1r4z8hy.com',
#  'bgqthdwjiqs.ug',
#  'sqciodqbbuvush.ru',
#  'feltgold.net',
#  'triedking.net',
#  'npgyrulwrymdbc.ru',
#  'bwgvmskrenos.ru',
#  'n6k5ri14usqw7sfwt4nwvynob.net',
#  '1a52rbte68jhd9hs1g611q9nj4.net',
#  'kelprncnjjytmvv.ru',
#  'oxmbcllloclg.ru',
#  'fejwiwrxbhqes.ru',
#  'llttaifqwwku.ru',
#  'z74xsjfot2yc19fy7651wsu8ev.biz',
#  'lbrwlwcgybaphxlbmtstcu.ru',
#  'evcjmfwftierti.net',
#  'qcwssdggxyyuwa.net',
#  'nlmyrqwxcxyfyrl.ru',
#  'yeygsqrrthcitrk.ru',
#  'd2950e8ce99955c359ed9ee1e1ec03b4.org',
#  '1icmok41nk5pi13davsj10tn79n.biz',
#  'ojgmlwoqafapw.ru',
#  '42f7dad2066e1cb41d347c685d1d880a.org',
#  'iajaskotrnraof.ru',
#  'ridujtwiguul.ru',
#  'iviablgpkijdpfc.ru',
#  '1je66qw1mbe6mqmrjwxgu1tlad.com',
#  'nfhxdcioxgnpghe.biz',
#  'msyaktbkpslbhs.ru',
#  'tkoyhefrliajt.ru',
#  'rakcocpljcjpgxt.biz',
#  'nqv3eohim99n839z3gpc43r3.com',
#  'wsmjcmhynfhjbobdheknkvwhycy.ru',
#  'dfwvoobmssgmui.com',
#  'lxilnugcjbvmkipg.ir',
#  'cirdxspd170z1x4lf2d166kcks.net',
#  'vbiksfmlkwata.ru',
#  'pfeemscydpyt.info',
#  '1l2pryz3yw1uid25qoa1wln3rf.org',
#  'qstdpgvnovkqlfr.ru',
#  '1r1veyjmhxwz1fszon11o91fck.com',
#  'qtjbmxhurhequoa.ru',
#  '1hobul0kt08jo1p6wheso21cvx.com',
#  'vnifvytqmiokva.ru',
#  'xrjgtevgrnrucfi.org',
#  'hufqjcrmgchih.com',
#  '9fae92c91843e8666e696dca13324300.org',
#  '18rdwgdgppuf215pvg2luurakf.com',
#  'shsdlftmuhokfim.ru',
#  '11j1v031uil6ab116j3vp66x8ir.org',
#  'milksaturday.net',
#  'txkvcoiujyvv.net',
#  'rockhigh.net',
#  'takenprice.net',
#  'nepsyfmdiafvwrh.im',
#  'qipalgndgkxxtvl.ru',
#  'pwf2zr170mhvnralq0763u9rj.net',
#  'wfimdcbaniqesld.ru',
#  'tgfjmkxgqvtrbm.ru',
#  'vtdubagge.xxx',
#  '1aqz3f0zuhq6k1v46h0r67bvsy.net',
#  'kyipjsqxkbve.ru',
#  'vivttocrurqdni.ru',
#  'sickpast.net',
#  'b76e3c92d1c96d1ad9b53713dd5c1e4b.org',
#  'ldb4cg19qvaux1vom3khodv6e7.org',
#  'isxoaktdbmxg.biz',
#  '1nuj3faw0pn9nuhf1qg1a4jyxn.biz',
#  'dcgaogrshpxrewmyin.org',
#  'eblnbnckqfdpbf.ru',
#  '796tq01pgkn0i22g5qvxiy965.org',
#  'ybqjcqxmqlil.ru',
#  'dtpjwgjbcilyinv.ru',
#  'galcqbhfnsbyn.ru',
#  'yffnuqhubywx.cx',
#  'tpnon976tk2i1au8kz63oa2du.com',
#  'aa246d230f40a0b43996b468e42700f5.org',
#  'glcfqivqqmqvpqw.ru',
#  'eic9r715in99a17uhlsm1js2czz.net',
#  'xsvmgxushekolo.net',
#  '6pt8kp1n0ma1tti4vq2ha1z5c.org',
#  'wfcoukkqnugu.ru',
#  'x35uny1s16rrc1bjz77n4jf7ym.net',
#  'lookdance.net',
#  'uyhrbjlgmbkbh.sc',
#  'fsymufyshgspcni.ru',
#  'dgdytca.ms',
#  'aifqozaefmyhytdguamirrkcifqijx.ru',
#  '1pnqqklf344d63knk9r1cyqt4y.com',
#  'awpgcmyqfdanhs.ru',
#  'jig0nz7nce321h8fdzolpsm7.org',
#  '15l2vqv94byak1u0r2lt1k0gpbn.biz',
#  'btoovqsxlmlkgb.mx',
#  'pnvzxsohqwohqhnxxclhittcjn.ru',
#  'joinhope.net',
#  '7u3ktd7qr3hit7qucdmal8s6.net',
#  'igvnrltchvomrt.ru',
#  'vxcrwxmaxgqbsac.ru',
#  'txcubtvjp.cm',
#  'wiqupdt.org',
#  '95863bec20bf8c08e13c7e4f2f5d8747.org',
#  'fepnfqpbscpjkrdnupx.ru',
#  'ixvfskppcykvsjhouridh.net',
#  'dywowlibdkflvxwobetopvdb.ru',
#  'wppwpjwheidkvehr.nu',
#  'hjaeltwmqcexfhkcpns.la',
#  'kpoedhyfowvnjpu.ru',
#  'qlxtvltxjxymdrj.biz',
#  'cbdpxrbydvykhjhykn.sx',
#  'latgbmgrfnlaado.co.uk',
#  'ci0zfurp5trgvec4mn1tvlong.net',
#  'feltboat.net',
#  'ynilxlanbckodt.ru',
#  'j9crh3meoua3190i7by1raoma2.com',
#  'knmmeedykjoiywb.ru',
#  '3kql3mt31bnt1myi75cq94tlb.org',
#  'groupmoon.net',
#  '13kb5a41jyuz6ag3mhqb1ken625.biz',
#  '4kpkpz1nlsk9ymjdb9ndhf956.net',
#  'keaxnucatcpsousnrfudcedjv.ru',
#  'hyrvbkx.so',
#  'wronghunt.net',
#  'cpyjjbi.su',
#  'lvmefl5hskpesqan3b1oapda7.org',
#  'uenppg19azi3egesxwn118mgmp.net',
#  'withfind.net',
#  '1c948j51hvqsof7abexz1dk0zv2.net',
#  'apthwbgphbgvk.ru',
#  'vbicxucaijpus.us',
#  'jfnyfyvxrxxx.ru',
#  'ndsgew19woggy118dh501cii2ej.net',
#  'spotleft.net',
#  '1slr2qxvvtsb1vhswq41bawe5d.com',
#  'movedish.net',
#  'jmuquobnngkbf.biz',
#  'bptqw0ropjaz183x42616kmvqa.net',
#  'uuepljrgdxiv.org',
#  'cwocijrhjminpr.sc',
#  'nxfuw5uq6v1rdya3ajwvvlqf.net',
#  '1opkfr1ly9i201nl28c71pvrmmj.com',
#  'dcgrjhknlkowrs.org',
#  'trllgdbouqrsqnw.tw',
#  'kivqchkasywggu.ru',
#  'nldqvijnonqg.ru',
#  'ijgeppsplptvo.ru',
#  'ad81a0e9e3a16e11a4fa9b577e8cfee4.org',
#  'vncwtitdabbdjab.ru',
#  'wynutlkpktuuprg.ru',
#  'cqlvqselulvkhf.ru',
#  '1f1ejkg5rzb0766mu4gjoxwb9.org',
#  'jwglsncwpavdmqu.ru',
#  '9ccfe4a7e8b88cb2ab81fc86bc77769a.org',
#  'tylwhjadu.cm',
#  'qkbbildwkijirgitppblp.ru',
#  '1pmizpm1jrednq1k10u1nbyozdi.com',
#  'fairunder.net',
#  'qeyvsieleqmbll.biz',
#  'axssoybolyjimvxrcilmf.so',
#  'sswlvzhvwwgfulbgyhiheijeyayrk.ru',
#  'qaoceytoxrgdg.ru',
#  'bthvvfcthhel.ru',
#  'bo2hgh1y5j1jq5pa0g31nnsb5r.biz',
#  'qebrnlolbixmvxaeftjb.ki',
#  'ihxebjngiyy.mu',
#  'vxkivafyiausrh.xxx',
#  'qcvwlnytbeprtwnzdxamemxoj.ru',
#  'nenluhjvrorsp.ru',
#  'cydmlgfqaiht.ru',
#  'prntmfesuiytp.ru',
#  'uwozphydudmrhqljnzlrxovkw.ru',
#  'mdwwkdwcl.sc',
#  '16dyh8j1yd1a5f85uh8zr7l0et.org',
#  'uwrhoqgpirkpg.ru',
#  'vnrxxuquoohxj.ru',
#  'iknctvviyculn.com',
#  'ntwjhcsgcpmkyp.ru',
#  'saijxend.mu',
#  'jk48vl1yk9ltpimxu7ts3byzf.org',
#  'tncwqbgunefa.ru',
#  'qstgeuibbmldnfgifeqcxoeyxg.ru',
#  'jpo97v9sh961cdo9d61jry3kd.net',
#  'soxbphlwikrdun.ru',
#  'xhqydcupkrcftct.net',
#  'tjkttdthgwr.kz',
#  'honpptvvjffp.ru',
#  'mgksqbjwsvyosk.ru',
#  'rvvbnnn.co',
#  'mademail.net',
#  'dudinuoxvgyldclrkfzxaytkdm.ru',
#  'engnipgnmpuepyi.ru',
#  'ffatd23pyccw1s574je1e4ijhk.org',
#  'ukkm511o275s3thxv201ctv2f0.net',
#  'obnhytvieaqx.tv',
#  'sqrpanpnnpoibdl.net',
#  'hcbcvrcpjltrr.ru',
#  'lordshade.net',
#  'kahfmyyffxjb.ru',
#  'equalhigh.net',
#  'nnmnle16kvi0gsi647nmhkpwi.com',
#  'lphjtncnubgbsd.ru',
#  'lixsneodgfcm.ru',
#  'u88w581fqpqeyemfuc019aw7ey.com',
#  'txoifnzqscjnxcwmvbatcmrs.ru',
#  'lhlmqhcswjvk.ru',
#  '388d5efb662316e7afa7455ade46ebb0.org',
#  'eatgdrwdmjucltkbcupvgibdu.ru',
#  'xupyhflfvsbe.info',
#  'dz1o6n1u1b2pji2np8u1rnneer.com',
#  'a9dcf157b522d93ab6b78b28a37f0381.org',
#  'jxfbabsorup.cc',
#  'spendheight.net',
#  'jnedfwidutrdxsa.ru',
#  'amcrnnkoltagc.ru',
#  'claiqqfbigufw.ru',
#  'iijspauoxqqi.ru',
#  'ublijrlobjnkqc.ru',
#  'htbogrcuthipfg.ru',
#  'rofcqehkutsg.co',
#  'humanfind.net',
#  'qxvbbtlxhwguongdywukl.co',
#  'wc08jo67jvmn1qmx84p1hnld6f.com',
#  'upbdmntlgupffv.ru',
#  'vwrilu14bo1rz4lvvje10t4tx7.org',
#  'tkfxugkrjoigk.ru',
#  '1ju84q71kbxwxyikf3att903yc.net',
#  'swfeizyxxnbicufepvjfushicalb.ru',
#  '1ml4fr112z2w42aia6z31vrorbf.org',
#  'ocbysiuwdvcr.ru',
#  'fbgnuejxwgrsvf.ru',
#  'efyxojy.biz',
#  'ukyneoetnhnhyud.ru',
#  '1bw82oy1i0fgroudeium18e4ruw.net',
#  'lmgwyrechslf.ru',
#  'mnjdwcumhjhnf.ru',
#  'qiukhohxxcdow.ru',
#  'ktlbcorceu.co',
#  'gscsbsanhyqsp.biz',
#  'llcot21wk5zn81q4zp9wr5022d.net',
#  'wifemine.net',
#  'looksome.net',
#  'ibipgfqrqxd.me',
#  'nqslwcqmtpujbxi.ru',
#  'uujgrvpwekqfmr.ru',
#  '631b6aa1878101ab766aee16886be994.org',
#  'cwnjditaxxrphok.ru',
#  'quickborn.net',
#  'gaomlknyuier.ru',
#  'qkdftcyreeiux.ru',
#  'evffrclkdpvconh.ru',
#  'tamhjcgwwjhviv.ru',
#  '16ejdg11xqwci31u0rtnt1klinij.com',
#  'gtajnxnxpwmmi.info',
#  '7w9ffgqrpvfm1mg5kjl181zk8y.biz',
#  'bsxhvivuppjn.ru',
#  'h1b4ev1xyzpezw4ucg0wxbnqb.org',
#  'gpiqpxqdtwre.net',
#  'jfgpmmnnyuqrbyh.ru',
#  'arivepull.net',
#  'krmjuf1jq67pn1ecr80e1lbl24k.com',
#  '1siyds4ic2qbp189wbqs821eee.biz',
#  'xnbfhp1t5jjtgqgbhl41ka4kb8.net',
#  'xhjrudtmoqpbkmh.ru',
#  'pvnpgitfveosn.ru',
#  'ajjpeymqkxssjoc.ru',
#  'wishgold.net',
#  'ynhjqpyepyvaibh.net',
#  'dhojylgqbmnjxoirqgxxhnjpvlv.ru',
#  'imcovdypvrjvx.ru',
#  'bylpzalvhubagewytkbvbydu.ru',
#  'watchslow.net',
#  'drpmpooqaibymla.ru',
#  'rgodvdlxaenai.ug',
#  'ogjsuhrerbrlkw.ru',
#  'nbdxptnqmtkrfnl.ru',
#  'ksfeeblmirwn.net',
#  'usaqrkvkrcfmzhizsckfxnlbemj.ru',
#  '6upy47udytd91fcanhz7jtdoe.net',
#  'z80h0v12thfq2158xgk11vjp6wt.net',
#  'cisqgsooomxj.ru',
#  '1hmmz021wkx7fxg1ee16enyvdx.com',
#  'ywroqeguegldbn.ru',
#  'dutykind.net',
#  '491de00bc9315566e30c137e02f46a16.org',
#  'je4phlugnj1zf251y21lvqq04.net',
#  'qdy2mv1umlj2hmaycf11086ae4.com',
#  'ccmwyfyhjsouac.ru',
#  'uhjcpfqlxqri.ru',
#  'kvfjqjqvtcurbgvqgtn.bit',
#  'wifepure.net',
#  'namfxekivxytb.ru',
#  'liyjbkobfmdkt.net',
#  'omyfjcovigxw.ru',
#  'feltought.net',
#  'itqrtupyeqyglv.net',
#  'dd8b212e825d429e5f62b272c0c08a89.org',
#  'wspchmccboaxbhqhnev.ms',
#  'i9n4ep1cfd04vhhkspc1szuewh.biz',
#  'dcob3f1vxreau8dzw2o17qv415.net',
#  'dkmgbthyhdior.ru',
#  'ucgtsnhlpigm.ru',
#  'llrlgudtztbupxwzhtuxlnz.ru',
#  'signhour.net',
#  'dhflottcjmdrhwe.ru',
#  'jdsugkeyyjoni.co.uk',
#  'wuybwskfvsgdcrv.ru',
#  'egjiuxtktsxy.ru',
#  '92zc5i1lhrz8g1bf44nv12logn5.com',
#  'gyloogwdrbjrdrf.ru',
#  'gjuamqxmhsupsk.ru',
#  'qityfiuitirpo.ru',
#  'odrxrekdvnhsrwu.net',
#  'tokmcxqmbtsmgdge.ms',
#  'bcqkedr.mn',
#  'awmunoeelfwso.com',
#  'qsojlamyuqwpzeyxwgeivonau.ru',
#  '1g0ier016p2lyyx711thuzmaow.com',
#  'hlvawqcodqpslfn.org',
#  'wucvibyhpimbwgx.ru',
#  'smnhifhsybvnnnv.ru',
#  'duxy6ejphmgo1thzr251w1czg2.com',
#  'dfssogeqdhwbqo.ru',
#  'tlgfjivfdscj.ru',
#  'wpsrcejyxhgiav.ru',
#  'avvsmre.xxx',
#  'lknfxieitmwttr.ru',
#  'vpcixdilaonq.org',
#  'phmkvhxafkol.ru',
#  'ariveover.net',
#  'nverrktobypvfacmjnjfzhsfy.ru',
#  '1mnpxq1171isoe47p4ga1ptt9td.net',
#  'auykohdtjubat.ru',
#  'ndkweainutvthf.ru',
#  'ddypbbdvarke.ru',
#  '4efdc2d82d4ec8719e212d9408107004.org',
#  'sgkdtnmtikmgu.ru',
#  'tglzheifvpvlninlbpbjnukknfqjr.ru',
#  'psdngbpcwdvvtpr.ru',
#  'hgmqwfujumlei.ru',
#  'gsi5byefptzh1cgi98es4cv1n.net',
#  'xcyfihykjrgnzeudebqcyivnr.ru',
#  'tswkfenlwspxk.ru',
#  'songwrote.net',
#  '15bg3wxkvdl1x1eo06s4g51eff.net',
#  'rogmreiskxrolydcagycuheady.ru',
#  'saltworld.net',
#  'erignufbih.bit',
#  'ycrrhkcmqeshlhp.info',
#  'cpapfioutwypmh.ru',
#  'nv642hlaui81xu55xp1ezcr7m.net',
#  'ucjqywqtktqlnjhu.sc',
#  'ywllfuxggcvsq.ru',
#  'pasmwdloaiho.ru',
#  '16cznwv43na0ws4s4sm1sqjlek.com',
#  'fzxwa5tn1qdnjhh46p1phl96w.com',
#  'rlxksyshwrfoc.ru',
#  'kagpajonqkin.ru',
#  'hspi2c187edscum2oj51u0swdq.net',
#  'hcpjmvlwkcqdpc.ru',
#  'sxtymixxhdfej.ru',
#  'darusdfwpojiju.ru',
#  'uudbtdsipanmi.ru',
#  'nkrcfsnbagsojwmgjny.mn',
#  'ibaqbeazzxpbempjgqwoldmhkv.ru',
#  'wusbpybsxdlf.ru',
#  'etaesqnwnxwqrj.ru',
#  'wifehand.net',
#  'btycoxgbcbdv.cx',
#  '9442b7a613d4bc5291b29ac3e45f75fd.org',
#  'pbtwmfimontt.ru',
#  '1vd9ykzzj1i9q1a8p9371dfq7gk.org',
#  '1bozxyk5pcopl18ihjkpn65xka.net',
#  'ook9nb1d9g0jyhdpquukp2x9m.com',
#  'olreqvwuwrshqpbsgylkz.ru',
#  'pkryljyuliqcrlc.biz',
#  'jguqblbuefuqhtx.ru',
#  'yqjxtfmlldaqinh.info',
#  'xriegokrhrcxfpw.ru',
#  'awajuoshijokcvo.ru',
#  'ptwhllahwwcy.org',
#  'awpvlweidtlc.ru',
#  'bpdtjtbioqid.ru',
#  'pqikgqmticdtjh.biz',
#  'darkconsiderable.net',
#  'dmqvlhcijbnb.ru',
#  'szltglbibfqgqsdduzxtdlr.ru',
#  '1cnwq7wm1hc14ce8u8yjbr3cb.com',
#  'ovonulvxosgguuoyxidubajbobpj.ru',
#  'ivwmeshafkhwdt.ru',
#  'endmoifrkcjqrm.ru',
#  'yskehfrktxakykv.ru',
#  'gjmwuhwsgcjgs.ru',
#  'ilpsydiubtmdm.ru',
#  'yhlvfudumlzthlbzlovemwoemgq.ru',
#  'mmamujqcafqvw.net',
#  'ccjwoapjih.la',
#  'dwuhtkxqbmoyb.ru',
#  'plyphqpexkpb.ru',
#  'olyfxrjwssoud.ru',
#  'arboggqvalhcvlf.ru',
#  'xjrdpecbygffpak.ru',
#  'dmagiefkqosjv.biz',
#  'xoynotbftorempwoiw.to',
#  'saltmail.net',
#  'arivelift.net',
#  'xlwjrr1kr780wmtfjdi1roz7mi.org',
#  'rqkdbfurshsd.biz',
#  'xgvmshwwywefic.ru',
#  'kojgeihjjuuudj.co.uk',
#  'uthvdrvahhql.biz',
#  'vijvkfgaaymffhv.ru',
#  'rmyayaldrbfeqm.ru',
#  'yo4p9idwlj1g1qrqezp92hj9j.com',
#  'lhdxbosbjerbmys.ru',
#  'woozlschutoydiauzxrclnj.ru',
#  '1b3zrsx1qcm8fq1so7cqa27l9gy.org',
#  'muyinleutmxei.ru',
#  'h7di8vykf79l1h8tl9wjqh3yj.org',
#  'daxqscxoeaydhieiukjyhvwdav.ru',
#  'gcjnjxkvyj.tv',
#  '6etruz1fk7mfa1jsicll10ql7jw.com',
#  'llnhqppdccanixq.ru',
#  '1l6fio1h6ac7u143un9vwkyem9.biz',
#  '26nqhq1v0h0xx13yvrwxtz6pwj.org',
#  'ceyoxovkuofx.ru',
#  'whicheight.net',
#  'kybvmqeigucfwf.ru',
#  'yiwyqmbhbgprebu.ru',
#  'lseyybtvyyqga.ru',
#  'fllq4h19x3lhd4cz200odbp3d.org',
#  'wfexugpqfghcqu.ru',
#  'rhkyxyukjlenu.ru',
#  'ryqeckdtvpqt.ru',
#  'soqehpgxgwskinh.ru',
#  '1voxfqvq3fchu93kun160t21a.org',
#  'obxsowfojbrdrp.ru',
#  'bkqetkdpfuqwe.ru',
#  'pkyxdbioiypyut.pro',
#  '1jlggc6a7x9harupgxdl347zj.org',
#  'kiqhayisitjp.ru',
#  'dvkxnagupxnhse.ru',
#  'ritqwwofmwjyc.ru',
#  'wbpstbjvlfwc.ru',
#  'mwwolmnmyicckn.ru',
#  'rylrlzkvslbeuytnbivojlkbpkn.ru',
#  'cnfhwxputxlirw.ru',
#  'wbidjynskpduol.ru',
#  'jumphurt.net',
#  'tpmqhracmwovg.ru',
#  '1eb15dlhckoyg1r6kvravdvrx.org',
#  'rutpmteabpwl.ru',
#  'cegvp61idm77i1qj84y91amgglk.net',
#  'jvtgeppbxintmbhijca.ru',
#  'uceajztqwindhurgqkbyaioem.ru',
#  'dtpdqtvhccww.ru',
#  'vjjtwtqtjkanqouwkr.jp',
#  'spokerest.net',
#  'mqmnsompavfchf.com',
#  'ocavllqqkqfwvixtvfp.mn',
#  'lbrbkwyxpjou.ru',
#  'ofmnwctldeaeeayhyprcwpnf.ru',
#  'spotjune.net',
#  'atnvsqhghmda.ru',
#  'ggbrnaqkqidv.ru',
#  'ljvzxqeuzdpaezpconlnu.ru',
#  'qeukrqpyiycyfjdddk.eu',
#  'lgewxemkjjzbiifojgqdmlnix.ru',
#  'xhitayzpxslruhwczxdcq.ru',
#  '1wzqguap3ht8ztpkjq9jvwyjb.org',
#  'yscjvkafnoey.ru',
#  '99bd854c410c637d32d7e97dc9f59599.org',
#  'jbqfeijhkmry.ru',
#  'lqsqmjqknceifj.ru',
#  'goewqxnakfmgp.ru',
#  '1oypgd17e77l0ice1656o87.net',
#  'oqjiofgaidrrqc.ru',
#  '16g07kq1y2xv8b5wbjwqfvik48.org',
#  'vshiufhgixrecs.ru',
#  'red2i61qkbln610bhw841eo2x9z.net',
#  'rlgmofnjxylygieufmhmnvuo.ru',
#  'b2072co269xo1426s6xx1z1n2.net',
#  'vplyngely.cm',
#  '3aabbf46f3068cec83fd1a90dc803a90.org',
#  '1leeuek1mq9jhqfl6x068ifc12.org',
#  'xgpjidftrbmbgwq.ru',
#  'ablejuly.net',
#  'moveheld.net',
#  'cve2ss1yffb2x16ffhuh1t43q1k.com',
#  'rrrsuskickkg.net',
#  'haqgirfauczsweqtdtgqgnjfysk.ru',
#  'mqjaqaafujpp.ru',
#  'emdugyheedrygl.ru',
#  '4c4mczjc8q4w1x5ko59886p2s.org',
#  'uqvoauwfxicgm.eu',
#  '1vi6jc2hanvwv4ovdl450wvm4.net',
#  'xjeaknnwwacrwch.ru',
#  'vtz0eb5fey0hhrxi921n1b144.net',
#  '16mc7681h67vtahctk411mal3c9.com',
#  'htfexgttvspvccmsoqmzpfjv.ru',
#  'tbweuenftuwpil.com',
#  'cbwzpj88ia4118v7ecd120vb20.com',
#  'bqcvyfmibxhhw.co',
#  '11tp36t29if316c76qidgr8k8.org',
#  'threefive.net',
#  'lcdyvwrrrwkxwha.biz',
#  'ahllhwljxdsnl.ru',
#  '1y5o545135vlxqo7e21214xw4dh.net',
#  'piyldrmlkfgupd.co.uk',
#  'qlbbubyvcpwgrslizkflnemof.ru',
#  '1913v1p1leujrrbi8eszq3zu37.org',
#  'casefind.net',
#  'ujvoqghkrjyoxy.com',
#  'nylpbhyuhclt.ru',
#  'wrcxvuygtxrnr.ru',
#  'oqubyevfwiok.ru',
#  'mnwsmscbbxvh.ru',
#  'vxnxhqnpcwthnsi.ru',
#  '1kus46viqzeu21ikredrjclyl1.com',
#  'mmrgthtc.xxx',
#  'xwsbginphqjlcm.ru',
#  'vonoyajappygpe.im',
#  'sfoxvmotuvijoccbrada.nu',
#  'tgwxcdaxrvxo.org',
#  'jnbecnaoctalc.ru',
#  'uvymjrdcngbvybl.ru',
#  'kcesnddloyfcild.ru',
#  'wrongworld.net',
#  'mshlvjxgxvpi.ru',
#  'imuctihtxkxt.ru',
#  'diadxirwcbnfvx.ru',
#  'triedwing.net',
#  'scqlx51bxqibw1073p1b1pewwj6.com',
#  '18bsmjto2wgxca1l215189mn62.net',
#  '13sg8o814ocp3hjfwimyzuqadh.org',
#  'eokcmguyuswwib.ru',
#  ...]

# %%
alpha=[]
numeric=[]
for i in host:
  c_alpha=0
  c_digit=0
  for j in i:
    if j.isdigit():
      c_digit+=1
    else:
      c_alpha+=1
  alpha.append(c_alpha)
  numeric.append(c_digit)
  
  #res.append[int(i) for i  in   if i.isdigit()]

# %%
per_n_c=[]
for i in range(len(alpha)):
  per_n_c.append(alpha[i]/alpha[i]+numeric[i])

# %%
df["percentage of numeric characters"]=per_n_c

# %% [markdown]
# # Shannon Entropy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from collections import Counter
from math import log
def shannon(string):
  counts = Counter(string)
  frequencies = ((i / len(string)) for i in counts.values())
  return - sum(f * log(f, 2) for f in frequencies)
#s = lambda i : - sum(f * log(f, 2) for f in ((j / len(i)) for j in Counter(i).values()))

# %%
s_list=[]
for i in df["host"]:
  s_list.append(shannon(i))
df["Shannon_Entropy"]=s_list

# %%
df
# Out:
#         isDGA                            host  num_characters  Vowels  \
# 0         dga  6xzxsw3sokvg1tc752y1a6p0af.com              30       4
# 1         dga               glbtlxwwhbnpxs.ru              17       1
# 2         dga               xxmamopyipbfpk.ru              17       4
# 3         dga   zfd5szpi18i85wj9uy13l69rg.net              29       4
# 4         dga                 jpqftymiuver.ru              15       4
# ...       ...                             ...             ...     ...
# 159995  legit                     manhunt.net              11       3
# 159996  legit                      yupptv.com              10       2
# 159997  legit                    bbcmundo.com              12       3
# 159998  legit                   kanogames.com              13       5
# 159999  legit                    roadrover.cn              12       4
#
#         Consonant  Unique characters ratio  percentage of numeric characters  \
# 0              16                 0.766667                              10.0
# 1              15                 0.764706                               1.0
# 2              12                 0.764706                               1.0
# 3              14                 0.793103                              11.0
# 4              10                 0.866667                               1.0
# ...           ...                      ...                               ...
# 159995          7                 0.727273                               1.0
# 159996          7                 0.900000                               1.0
# 159997          8                 0.666667                               1.0
# 159998          7                 0.769231                               1.0
# 159999          7                 0.750000                               1.0
#
#         Shannon_Entropy
# 0              4.440224
# 1              3.616875
# 2              3.572469
# 3              4.444188
# 4              3.640224
# ...                 ...
# 159995         2.845351
# 159996         3.121928
# 159997         2.918296
# 159998         3.238901
# 159999         3.022055
#
# [160000 rows x 8 columns]

# %% [markdown]
# # Percentage of length of largest meaningful string

# %% [markdown]
# ## Number of periods

# %%
# for i in df["host"]:
#   count=0
#   for j in i:
#     if j==".":
#       count+=1
#   print(count)

# %% [markdown]
# # similarity with legit domain.

# %% [markdown]
# # Entropy:
# ### It is the measure of randomness that is DGA domain has higher uncertainity than of normal domain.
# ## In DGA there is no meaningful pattern.

# %%
# import pandas as pd
# import scipy.stats

# def ent(data):
#     """Calculates entropy of the passed `pd.Series`
#     """
#     p_data = data.value_counts()           # counts occurrence of each value
#     entropy = scipy.stats.entropy(p_data)  # get entropy from counts
#     return entropy

# %%
# for i in df["host"]:
#   list_of_characters = []
#   for j in i:
#     list_of_characters.append(j)
  
  

#   df1 = pd.DataFrame(list_of_characters, columns=['values'])

#   res = df1['values'].value_counts().to_frame().reset_index().sort_values('index')
#   ent(res)

# %%
from sklearn.model_selection import train_test_split

# %%
df1=df.drop(["isDGA"],axis=1)

# %%
df1
# Out:
#                                   host  num_characters  Vowels  Consonant  \
# 0       6xzxsw3sokvg1tc752y1a6p0af.com              30       4         16
# 1                    glbtlxwwhbnpxs.ru              17       1         15
# 2                    xxmamopyipbfpk.ru              17       4         12
# 3        zfd5szpi18i85wj9uy13l69rg.net              29       4         14
# 4                      jpqftymiuver.ru              15       4         10
# ...                                ...             ...     ...        ...
# 159995                     manhunt.net              11       3          7
# 159996                      yupptv.com              10       2          7
# 159997                    bbcmundo.com              12       3          8
# 159998                   kanogames.com              13       5          7
# 159999                    roadrover.cn              12       4          7
#
#         Unique characters ratio  percentage of numeric characters  \
# 0                      0.766667                              10.0
# 1                      0.764706                               1.0
# 2                      0.764706                               1.0
# 3                      0.793103                              11.0
# 4                      0.866667                               1.0
# ...                         ...                               ...
# 159995                 0.727273                               1.0
# 159996                 0.900000                               1.0
# 159997                 0.666667                               1.0
# 159998                 0.769231                               1.0
# 159999                 0.750000                               1.0
#
#         Shannon_Entropy
# 0              4.440224
# 1              3.616875
# 2              3.572469
# 3              4.444188
# 4              3.640224
# ...                 ...
# 159995         2.845351
# 159996         3.121928
# 159997         2.918296
# 159998         3.238901
# 159999         3.022055
#
# [160000 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder=LabelEncoder()

# %%
df["isDGA"]=LabelEncoder.fit_transform(df["isDGA"])

# %%
X=df1.drop(["host"],axis=1)
y=df["isDGA"]

# %%
X.head(4)
# Out:
#    num_characters  Vowels  Consonant  Unique characters ratio  \
# 0              30       4         16                 0.766667
# 1              17       1         15                 0.764706
# 2              17       4         12                 0.764706
# 3              29       4         14                 0.793103
#
#    percentage of numeric characters  Shannon_Entropy
# 0                              10.0         4.440224
# 1                               1.0         3.616875
# 2                               1.0         3.572469
# 3                              11.0         4.444188

# %%
y.head(4)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# Name: isDGA, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.707625
# [[ 7952  8067]
#  [ 1289 14692]]
# 0.6455468166439651

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.73634375
# [[ 8910  7109]
#  [ 1328 14653]]
# 0.673329657200625

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.5019375
# [[15975    44]
#  [15894    87]]
# 0.6641221374045801

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.49940625, 0.49940625)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.49940625
# Precision -  0.49940625
# For  KN
# Accuracy -  0.84734375
# Precision -  0.8312238805970149
# For  NB
# Accuracy -  0.73634375
# Precision -  0.673329657200625
# For  DT
# Accuracy -  0.8515625
# Precision -  0.8149997195265608
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# For  LR
# Accuracy -  0.84471875
# Precision -  0.8228568077870294
# For  RF
# Accuracy -  0.86096875
# Precision -  0.8237870619946092
# For  AdaBoost
# Accuracy -  0.8483125
# Precision -  0.8072229278259428
# For  BgC
# Accuracy -  0.86096875
# Precision -  0.8237870619946092
# For  ETC
# Accuracy -  0.86003125
# Precision -  0.824878544797198
# For  GBDT
# Accuracy -  0.856625
# Precision -  0.8116758767850304
# For  xgb
# Accuracy -  0.8630625
# Precision -  0.8189166895793236

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0         KN   Accuracy  0.847344
# 1        ETC   Accuracy  0.860031
# 2         RF   Accuracy  0.860969
# 3        BgC   Accuracy  0.860969
# 4         LR   Accuracy  0.844719
# 5        xgb   Accuracy  0.863062
# 6         DT   Accuracy  0.851562
# 7       GBDT   Accuracy  0.856625
# 8   AdaBoost   Accuracy  0.848313
# 9         NB   Accuracy  0.736344
# 10       SVC   Accuracy  0.499406
# 11        KN  Precision  0.831224
# 12       ETC  Precision  0.824879
# 13        RF  Precision  0.823787
# 14       BgC  Precision  0.823787
# 15        LR  Precision  0.822857
# 16       xgb  Precision  0.818917
# 17        DT  Precision  0.815000
# 18      GBDT  Precision  0.811676
# 19  AdaBoost  Precision  0.807223
# 20        NB  Precision  0.673330
# 21       SVC  Precision  0.499406

# %%
import seaborn as sns

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-d98b5dbedb3f> in <module>
#       1 sns.catplot(x = 'Algorithm', y='value',
#       2                hue = 'variable',data=performance_df1, kind='bar',height=5)
# ----> 3 plt.ylim(0.5,1.0)
#       4 plt.xticks(rotation='vertical')
#       5 plt.show()
#
# NameError: name 'plt' is not defined
